# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, pickle, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))
from libs import agg, data, fl, log, nn, plot, poison, resnet, sim, wandb
from libs.distributed import *
from cfgs.fedargs import *
# Out:
# /home/harsh_1921cs01/hub/AgroFed/fl/libs/distributed.py:50: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if epoch is not -1 or str(epoch) == str(_epoch):

# %%
#fedargs.name = "client-1"
project = 'fl-kafka-client'
name = 'fedavg-cnn-mnist-na-' + fedargs.name

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

fedargs.tb = SummaryWriter('../out/runs/' + project + '/' + name, comment="fl")
plot = plot.init(name, project)
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-kafka-client/runs/1df2bvq5" target="_blank">fedavg-cnn-mnist-na-client-x</a></strong> to <a href="https://wandb.ai/kasyah/fl-kafka-client" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
# Kafka topic to publish and subscribe
fedargs.topic = 'pyflx'
fedargs.num_clients = 1

# %%
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
host = socket.gethostname()
clients = [host + ": " + fedargs.name]

# %%
# Distributed topology
dt = Distributed(clients)

# %%
# Initialize Global and Client models
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset)

# %%
clients_data = data.split_data(train_data, clients)

# %%
client_train_loaders, client_test_loaders = data.load_client_data(clients_data, fedargs.client_batch_size, 0.2, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "test_loader": client_test_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def process(client, epoch, dt, model, train_loader, test_loader, fedargs, device):
    log.info("Epoch: {}, Processing Client {}".format(epoch, client))
    
    # Consume and Average, epoch passed is actually prev epoch, for which we want to consume updates
    client_model_updates = dt.consume_model(client, fedargs.topic, model, epoch)
    
    # Pop one's own update
    if client in client_model_updates:
        client_model_updates.pop(client)

    log.info("Epoch: {}, Client {} received {} model update(s) from {}".format(epoch, client, 
                                                                               len(client_model_updates), 
                                                                               list(client_model_updates.keys())))
    
    if len(client_model_updates) != 0:
        model = fl.federated_avg(client_model_updates, model)

    # Train    
    model_update, model, loss = fedargs.train_func(model, train_loader, 
                                                   fedargs.learning_rate,
                                                   fedargs.weight_decay,
                                                   fedargs.local_rounds, device)

    # Publish
    epoch = epoch + 1
    dt.produce_model(client, fedargs.topic, model_update, epoch)

    log.jsondebug(loss, "Epoch {} : Federated Training loss, Client {}".format(epoch, client))
    log.modeldebug(model, "Epoch {}: Client {} Update".format(epoch, client))

    # Test, Plot and Log
    test_output = fedargs.eval_func(model, test_loader, device)
    fedargs.tb.add_scalar("Accuracy/" + client, test_output["accuracy"], epoch)
    fedargs.tb.add_scalar("Test Loss/" + client, test_output["test_loss"], epoch)
    plot.alog(client, {epoch: {"time": time.time(), "acc": test_output["accuracy"], "loss": test_output["test_loss"]}})
    wb.log({client: {"epoch": epoch, "time": time.time(), "acc": test_output["accuracy"], "loss": test_output["test_loss"]}})
    log.jsoninfo(test_output, "Test Outut after Epoch {} of {} for Client {}".format(epoch, fedargs.epochs, client))

    return model

# %%
import time
start_time = time.time()

# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    for client in clients:
        client_details[client]['model'] = process(client, epoch, dt, client_details[client]['model'],
                                                  client_details[client]['train_loader'],
                                                  client_details[client]['test_loader'],
                                                  fedargs, device)
print(time.time() - start_time)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]2021-10-29 10:50:42,025 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 0 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:50:42,050 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 0, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:02,123 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 0, Client bladecluster.iitp.org: client-x received 50 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(32)', 'bladecluster.iitp.org(17)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(18)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(21)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(31)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(46)'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:31,258 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:31,487 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:32,521 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 906 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:36,558 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 1 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 91.43333333333334,
#     "correct": 10972,
#     "test_loss": 0.28507454512516656
# } [MainProcess : MainThread (INFO)]
#   2%|▏         | 1/51 [00:54<45:45, 54.92s/it]2021-10-29 10:51:36,605 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 1 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:36,628 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 1, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:51:56,717 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 1, Client bladecluster.iitp.org: client-x received 30 model update(s) from ['bladecluster.iitp.org(8)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(1)'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:52:23,538 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:52:23,728 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:52:24,771 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 907 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:52:28,237 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 2 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 92.125,
#     "correct": 11055,
#     "test_loss": 0.26043408704797427
# } [MainProcess : MainThread (INFO)]
#   4%|▍         | 2/51 [01:46<43:16, 53.00s/it]2021-10-29 10:52:28,253 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 2 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:52:28,273 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 2, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:52:48,386 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 2, Client bladecluster.iitp.org: client-x received 10 model update(s) from ['bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(10)'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:53:32,326 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:53:32,524 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:53:34,332 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 908 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:53:39,209 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 3 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 92.61666666666667,
#     "correct": 11114,
#     "test_loss": 0.24800875731309255
# } [MainProcess : MainThread (INFO)]
#   6%|▌         | 3/51 [02:57<48:57, 61.20s/it]2021-10-29 10:53:39,235 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 3 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:53:39,253 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 3, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:53:59,354 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 3, Client bladecluster.iitp.org: client-x received 11 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:54:39,965 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:54:40,154 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:54:41,052 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 910 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:54:46,954 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 4 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 92.025,
#     "correct": 11043,
#     "test_loss": 0.2732634908060233
# } [MainProcess : MainThread (INFO)]
#   8%|▊         | 4/51 [04:05<49:57, 63.79s/it]2021-10-29 10:54:46,970 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 4 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:54:46,989 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 4, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:55:07,106 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 4, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:55:49,636 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:55:49,827 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:55:50,681 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 912 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:55:55,497 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 5 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 92.98333333333333,
#     "correct": 11158,
#     "test_loss": 0.24061054443319638
# } [MainProcess : MainThread (INFO)]
#  10%|▉         | 5/51 [05:13<50:13, 65.50s/it]2021-10-29 10:55:55,512 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 5 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:55:55,532 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 5, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:56:15,599 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 5, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:56:56,623 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:56:56,776 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:56:57,696 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 914 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:57:02,644 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 6 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 96.04166666666667,
#     "correct": 11525,
#     "test_loss": 0.13757209675510723
# } [MainProcess : MainThread (INFO)]
#  12%|█▏        | 6/51 [06:20<49:32, 66.06s/it]2021-10-29 10:57:02,662 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 6 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:57:02,687 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 6, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:57:22,784 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 6, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:58:05,262 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:58:05,441 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:58:06,480 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 916 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:58:10,759 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 7 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 91.44166666666666,
#     "correct": 10973,
#     "test_loss": 0.2903195264438788
# } [MainProcess : MainThread (INFO)]
#  14%|█▎        | 7/51 [07:29<48:56, 66.73s/it]2021-10-29 10:58:10,773 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 7 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:58:10,792 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 7, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:58:30,851 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 7, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 10:59:09,554 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 10:59:09,741 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 10:59:10,727 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 918 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:59:16,660 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 8 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 92.80833333333334,
#     "correct": 11137,
#     "test_loss": 0.24295479680101076
# } [MainProcess : MainThread (INFO)]
#  16%|█▌        | 8/51 [08:34<47:38, 66.47s/it]2021-10-29 10:59:16,684 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 8 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 10:59:16,715 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 8, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 10:59:36,827 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 8, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:00:20,059 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:00:20,193 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:00:21,112 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 920 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:00:25,466 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 9 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 91.55833333333334,
#     "correct": 10987,
#     "test_loss": 0.2884028622309367
# } [MainProcess : MainThread (INFO)]
#  18%|█▊        | 9/51 [09:43<47:02, 67.20s/it]2021-10-29 11:00:25,482 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 9 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:00:25,502 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 9, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:00:45,582 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 9, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:01:28,793 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:01:28,941 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:01:29,845 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 923 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:01:33,642 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 10 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.84166666666667,
#     "correct": 11501,
#     "test_loss": 0.1394776295721531
# } [MainProcess : MainThread (INFO)]
#  20%|█▉        | 10/51 [10:51<46:07, 67.50s/it]2021-10-29 11:01:33,657 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 10 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:01:33,675 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 10, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:01:53,740 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 10, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:02:36,893 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:02:37,051 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:02:38,298 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 925 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:02:42,075 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 11 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 91.75833333333333,
#     "correct": 11011,
#     "test_loss": 0.27725679539640746
# } [MainProcess : MainThread (INFO)]
#  22%|██▏       | 11/51 [12:00<45:11, 67.79s/it]2021-10-29 11:02:42,089 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 11 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:02:42,111 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 11, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:03:02,211 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 11, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:03:43,104 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:03:43,257 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:03:44,166 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 927 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:03:47,728 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 12 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 96.11666666666666,
#     "correct": 11534,
#     "test_loss": 0.13161608369772632
# } [MainProcess : MainThread (INFO)]
#  24%|██▎       | 12/51 [13:06<43:38, 67.14s/it]2021-10-29 11:03:47,742 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 12 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:03:47,761 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 12, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:04:07,843 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 12, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:04:48,572 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:04:48,756 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:04:49,694 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 929 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:04:53,495 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 13 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 91.23333333333333,
#     "correct": 10948,
#     "test_loss": 0.30792245066165924
# } [MainProcess : MainThread (INFO)]
#  25%|██▌       | 13/51 [14:11<42:15, 66.72s/it]2021-10-29 11:04:53,510 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 13 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:04:53,530 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 13, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:05:13,605 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 13, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:05:56,033 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:05:56,175 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:05:57,090 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 931 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:06:00,848 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 14 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.675,
#     "correct": 11481,
#     "test_loss": 0.15225862276057403
# } [MainProcess : MainThread (INFO)]
#  27%|██▋       | 14/51 [15:19<41:15, 66.91s/it]2021-10-29 11:06:00,861 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 14 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:06:00,880 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 14, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:06:21,021 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 14, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:07:02,037 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:07:02,170 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:07:03,254 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 933 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:07:07,239 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 15 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 89.25833333333333,
#     "correct": 10711,
#     "test_loss": 0.39457547722260156
# } [MainProcess : MainThread (INFO)]
#  29%|██▉       | 15/51 [16:25<40:03, 66.76s/it]2021-10-29 11:07:07,255 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 15 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:07:07,275 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 15, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:07:27,352 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 15, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:08:07,214 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:08:07,409 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:08:08,284 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 935 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:08:11,998 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 16 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.73333333333333,
#     "correct": 11488,
#     "test_loss": 0.1444947193910678
# } [MainProcess : MainThread (INFO)]
#  31%|███▏      | 16/51 [17:30<38:35, 66.15s/it]2021-10-29 11:08:12,012 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 16 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:08:12,031 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 16, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:08:32,094 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 16, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:09:12,952 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:09:13,126 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:09:14,010 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 937 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:09:17,619 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 17 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.301622801462809
# } [MainProcess : MainThread (INFO)]
#  33%|███▎      | 17/51 [18:35<37:23, 65.99s/it]2021-10-29 11:09:17,633 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 17 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:09:17,651 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 17, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:09:37,774 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 17, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:10:19,023 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:10:19,159 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:10:20,086 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 939 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:10:23,860 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 18 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.08333333333333,
#     "correct": 11410,
#     "test_loss": 0.16143897846341132
# } [MainProcess : MainThread (INFO)]
#  35%|███▌      | 18/51 [19:42<36:20, 66.07s/it]2021-10-29 11:10:23,877 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 18 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:10:23,896 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 18, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:10:43,978 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 18, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:11:23,003 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:11:23,173 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:11:24,070 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 941 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:11:27,617 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 19 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.3022796885172525
# } [MainProcess : MainThread (INFO)]
#  37%|███▋      | 19/51 [20:45<34:51, 65.37s/it]2021-10-29 11:11:27,633 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 19 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:11:27,652 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 19, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:11:47,736 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 19, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:12:24,501 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:12:24,731 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:12:26,861 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 943 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:12:30,552 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 20 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.90833333333333,
#     "correct": 11509,
#     "test_loss": 0.13502135217686495
# } [MainProcess : MainThread (INFO)]
#  39%|███▉      | 20/51 [21:48<33:23, 64.64s/it]2021-10-29 11:12:30,568 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 20 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:12:30,589 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 20, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:12:50,664 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 20, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:13:29,091 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:13:29,323 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:13:30,160 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 945 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:13:34,293 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 21 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.3024959163665772
# } [MainProcess : MainThread (INFO)]
#  41%|████      | 21/51 [22:52<32:11, 64.37s/it]2021-10-29 11:13:34,308 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 21 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:13:34,327 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 21, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:13:54,461 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 21, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:14:30,873 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:14:31,096 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:14:32,616 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 947 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:14:36,507 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 22 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.13333333333334,
#     "correct": 11416,
#     "test_loss": 0.1594821119705836
# } [MainProcess : MainThread (INFO)]
#  43%|████▎     | 22/51 [23:54<30:47, 63.72s/it]2021-10-29 11:14:36,522 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 22 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:14:36,541 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 22, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:14:56,645 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 22, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:15:34,633 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:15:34,871 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:15:35,706 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 949 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:15:39,354 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 23 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.3024815661112465
# } [MainProcess : MainThread (INFO)]
#  45%|████▌     | 23/51 [24:57<29:36, 63.46s/it]2021-10-29 11:15:39,367 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 23 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:15:39,386 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 23, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:15:59,504 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 23, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:16:35,475 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:16:35,692 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:16:36,798 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 951 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:16:40,678 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 24 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 94.90833333333333,
#     "correct": 11389,
#     "test_loss": 0.17051412026584148
# } [MainProcess : MainThread (INFO)]
#  47%|████▋     | 24/51 [25:59<28:16, 62.82s/it]2021-10-29 11:16:40,695 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 24 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:16:40,725 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 24, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:17:00,825 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 24, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:17:36,962 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:17:37,190 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:17:38,029 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 953 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:17:41,550 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 25 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 10.341666666666667,
#     "correct": 1241,
#     "test_loss": 2.302579091389974
# } [MainProcess : MainThread (INFO)]
#  49%|████▉     | 25/51 [26:59<26:58, 62.23s/it]2021-10-29 11:17:41,563 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 25 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:17:41,581 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 25, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:18:01,630 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 25, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:18:37,680 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:18:37,910 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:18:38,759 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 955 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:18:42,516 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 26 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 94.61666666666667,
#     "correct": 11354,
#     "test_loss": 0.18100977276762326
# } [MainProcess : MainThread (INFO)]
#  51%|█████     | 26/51 [28:00<25:46, 61.85s/it]2021-10-29 11:18:42,530 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 26 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:18:42,549 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 26, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:19:02,594 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 26, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:19:38,377 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:19:38,533 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:19:39,583 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 957 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:19:43,128 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 27 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.3025506114959717
# } [MainProcess : MainThread (INFO)]
#  53%|█████▎    | 27/51 [29:01<24:35, 61.48s/it]2021-10-29 11:19:43,141 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 27 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:19:43,160 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 27, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:20:03,210 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 27, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:20:40,034 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:20:40,176 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:20:41,458 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 959 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:20:45,168 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 28 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 94.975,
#     "correct": 11397,
#     "test_loss": 0.16815634301801521
# } [MainProcess : MainThread (INFO)]
#  55%|█████▍    | 28/51 [30:03<23:37, 61.65s/it]2021-10-29 11:20:45,182 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 28 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:20:45,201 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 28, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:21:05,269 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 28, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:21:41,918 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:21:42,136 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:21:42,980 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 961 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:21:46,554 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 29 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.3025031547546386
# } [MainProcess : MainThread (INFO)]
#  57%|█████▋    | 29/51 [31:04<22:34, 61.57s/it]2021-10-29 11:21:46,571 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 29 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:21:46,605 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 29, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:22:06,716 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 29, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:22:42,819 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:22:42,980 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:22:44,050 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 963 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:22:47,771 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 30 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 94.56666666666666,
#     "correct": 11348,
#     "test_loss": 0.17847190443674724
# } [MainProcess : MainThread (INFO)]
#  59%|█████▉    | 30/51 [32:06<21:30, 61.46s/it]2021-10-29 11:22:47,786 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 30 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:22:47,804 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 30, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:23:07,854 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 30, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:23:44,716 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:23:44,862 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:23:45,784 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 965 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:23:49,512 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 31 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 11.408333333333333,
#     "correct": 1369,
#     "test_loss": 2.30251966603597
# } [MainProcess : MainThread (INFO)]
# ...
# 2021-10-29 11:23:49,544 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 31, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:24:09,610 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 31, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:24:44,293 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:24:44,517 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:24:45,375 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 967 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:24:49,090 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 32 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 95.13333333333334,
#     "correct": 11416,
#     "test_loss": 0.16872214940687022
# } [MainProcess : MainThread (INFO)]
#  63%|██████▎   | 32/51 [34:07<19:18, 60.96s/it]2021-10-29 11:24:49,103 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 32 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:24:49,121 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 32, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:25:09,216 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 32, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:25:44,796 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:25:45,025 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:25:45,856 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 969 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:25:49,591 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 33 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 9.641666666666666,
#     "correct": 1157,
#     "test_loss": 2.302580988566081
# } [MainProcess : MainThread (INFO)]
#  65%|██████▍   | 33/51 [35:07<18:14, 60.82s/it]2021-10-29 11:25:49,606 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 33 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:25:49,624 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 33, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:26:09,759 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 33, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:26:44,577 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:26:44,804 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:26:45,650 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 971 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:26:49,264 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 34 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 94.95833333333333,
#     "correct": 11395,
#     "test_loss": 0.16835020925104618
# } [MainProcess : MainThread (INFO)]
#  67%|██████▋   | 34/51 [36:07<17:08, 60.48s/it]2021-10-29 11:26:49,287 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 34 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:26:49,317 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 34, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:27:09,412 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 34, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
# 2021-10-29 11:27:44,869 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : MainThread (INFO)]
# 2021-10-29 11:27:45,061 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : MainThread (INFO)]
# 2021-10-29 11:27:45,935 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org: client-x' successfully produced to pyflx [0] at offset 973 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:27:49,496 - <ipython-input-10-a04f38dd6afa>::process(l:37) : Test Outut after Epoch 35 of 51 for Client bladecluster.iitp.org: client-x {
#     "accuracy": 9.833333333333332,
#     "correct": 1180,
#     "test_loss": 2.302587879816691
# } [MainProcess : MainThread (INFO)]
#  69%|██████▊   | 35/51 [37:07<16:06, 60.40s/it]2021-10-29 11:27:49,509 - <ipython-input-11-387a89c474b9>::<module>(l:6) : Federated Training Epoch 35 of 51 [MainProcess : MainThread (INFO)]
# 2021-10-29 11:27:49,526 - <ipython-input-10-a04f38dd6afa>::process(l:2) : Epoch: 35, Processing Client bladecluster.iitp.org: client-x [MainProcess : MainThread (INFO)]
# 2021-10-29 11:28:00,379 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/distributed.py::consume_model(l:54) : Exception KeyboardInterrupt occured consuming update for client bladecluster.iitp.org: client-x [MainProcess : MainThread (ERROR)]
# 2021-10-29 11:28:00,412 - <ipython-input-10-a04f38dd6afa>::process(l:11) : Epoch: 35, Client bladecluster.iitp.org: client-x received 1 model update(s) from ['bladecluster.iitp.org: client-1'] [MainProcess : MainThread (INFO)]
#  69%|██████▊   | 35/51 [37:28<17:07, 64.25s/it]
# 2021-10-29 11:28:10,314 - Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#  [MainProcess : MainThread (ERROR)]
# 2021-10-29 11:28:10,318 -
# Unfortunately, your original traceback can not be constructed.
#  [MainProcess : MainThread (INFO)]
# Traceback (most recent call last):
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-11-387a89c474b9>", line 9, in <module>
#     client_details[client]['model'] = process(client, epoch, dt, client_details[client]['model'],
#   File "<ipython-input-10-a04f38dd6afa>", line 19, in process
#     model_update, model, loss = fedargs.train_func(model, train_loader,
#   File "/home/harsh_1921cs01/hub/AgroFed/fl/libs/fl.py", line 182, in train_model
#     model, loss = client_update(_model, train_loader, lr, wd, r, device)
#   File "/home/harsh_1921cs01/hub/AgroFed/fl/libs/fl.py", line 72, in client_update
#     output = model(data)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/harsh_1921cs01/hub/AgroFed/fl/libs/nn.py", line 131, in forward
#     x = self.conv2(x)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/conv.py", line 395, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/harsh_1921cs01/anaconda3/envs/syft/lib/python3.9/inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-11-387a89c474b9> in <module>
#       8     for client in clients:
# ----> 9         client_details[client]['model'] = process(client, epoch, dt, client_details[client]['model'],
#      10                                                   client_details[client]['train_loader'],
#
# <ipython-input-10-a04f38dd6afa> in process(client, epoch, dt, model, train_loader, test_loader, fedargs, device)
#      18     # Train
# ---> 19     model_update, model, loss = fedargs.train_func(model, train_loader,
#      20                                                    fedargs.learning_rate,
#
# ~/hub/AgroFed/fl/libs/fl.py in train_model(_model, train_loader, lr, wd, r, device)
#     181 def train_model(_model, train_loader, lr, wd, r, device):
# --> 182     model, loss = client_update(_model, train_loader, lr, wd, r, device)
#     183     model_update = agg.sub_model(_model, model)
#
# ~/hub/AgroFed/fl/libs/fl.py in client_update(_model, data_loader, learning_rate, decay, epochs, device)
#      71             optimizer.zero_grad()
# ---> 72             output = model(data)
#      73             _loss = F.nll_loss(output, target)
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#
# ~/hub/AgroFed/fl/libs/nn.py in forward(self, x)
#     130         x = F.relu(x)
# --> 131         x = self.conv2(x)
#     132         x = F.relu(x)
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     394                             _pair(0), self.dilation, self.groups)
# --> 395         return F.conv2d(input, weight, bias, self.stride,
#     396                         self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/envs/syft/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# <h1> End </h1>
